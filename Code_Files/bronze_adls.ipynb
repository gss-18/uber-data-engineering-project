# %%
import pandas as pd

files = [
{"file":"map_cities"},
{"file":"map_cancellation_reasons"},
{"file":"map_payment_methods"},
{"file":"map_ride_statuses"},
{"file":"map_vehicle_makes"},
{"file":"map_vehicle_types"}
]
 
for file in files:
    url = f"https://dluber.blob.core.windows.net/raw/ingest/{file['file']}?sp=r&st=2026-03-23T00:53:03Z&se=2026-04-30T09:08:03Z&spr=https&sv=2024-11-04&sr=c&sig=FVthZcbgmUd4vOLA%2B%2FD2pL%2BP%2FwHouR1TNGyyzmtu520%3D"

    df = pd.read_json(url)
    df_spark = spark.createDataFrame(df)
    df_spark.write.format("delta")\
        .mode("overwrite")\
        .option("overwriteSchema", "true")\
        .saveAsTable(f"uber.bronze.{file['file']}")

# %%
url = "https://dluber.blob.core.windows.net/raw/ingest/bulk_rides?sp=r&st=2026-03-23T00:53:03Z&se=2026-04-30T09:08:03Z&spr=https&sv=2024-11-04&sr=c&sig=FVthZcbgmUd4vOLA%2B%2FD2pL%2BP%2FwHouR1TNGyyzmtu520%3D"

df = pd.read_json(url)
df_spark = spark.createDataFrame(df)
if not spark.catalog.tableExists(f"uber.bronze.bulk_rides"):
    df_spark.write.format("delta")\
        .mode("overwrite")\
        .option("overwriteSchema", "true")\
        .saveAsTable(f"uber.bronze.{file['file']}")
    print("This will not run more than once")

# %%
# %sql
SELECT * FROM uber.bronze.map_cities
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
